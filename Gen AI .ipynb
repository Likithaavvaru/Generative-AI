# %%
# !pip install cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.2/210.2 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# ...

# %%
import cohere
COHERE_API_KEY = "nIUTjtAroaMwIAP59UOu6kjPXXl84A2OTInzob67"

# %%
co = cohere.Client(COHERE_API_KEY)
response = co.generate(
    prompt = "Write something about Beaches",
    max_tokens = 200,
    temperature = 0.5,
    stop_sequences = ["\n"]
)
print(response.generations[0].text)
# Out:
#  Most of us love the beach – the serene and picturesque beauty of the blue ocean waters stretched out as far as the eye can see, meeting the limitless blue sky above, punctuated by fluffy white clouds. The gentle breeze whispering through our hair, carrying the invigorating scent of sea salt and marine freshness. The soothing sound of waves caressing the shore in a rhythmic, lulling melody that invites us to relax and unwind.
